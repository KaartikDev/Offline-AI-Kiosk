# %%
from pathlib import Path
import os

ROOT = "/Users/ktejwani/Personal CS Projects/Summer 2025/Offline AI Kiosk/Offline-AI-Kiosk/first_aid_knowledge_pack_v3"

def human_size(num_bytes: int) -> str:
    units = ["B", "KB", "MB", "GB", "TB"]
    size = float(num_bytes)
    for u in units:
        if size < 1024 or u == units[-1]:
            return f"{size:.0f}{u}" if size >= 10 else f"{size:.1f}{u}"
        size /= 1024

def print_tree(root_path: str):
    root = Path(root_path)
    if not root.exists() or not root.is_dir():
        raise NotADirectoryError(f"{root} is not a directory")
    print(f"{root.name}/")
    for current, dirs, files in os.walk(root):
        dirs.sort()
        files.sort()
        rel = Path(current).relative_to(root)
        depth = 0 if str(rel) == "." else len(rel.parts)
        if current != str(root):
            print(f'{"    " * depth}{Path(current).name}/')
        for f in files:
            print(f'{"    " * (depth + 1)}{f}')

def print_documents_with_sizes(root_path: str, exts=None):
    """
    Print all 'documents' in tree order with sizes.
    Default extensions: .pdf, .doc, .docx, .md, .txt, .rtf
    """
    if exts is None:
        exts = {".pdf", ".doc", ".docx", ".md", ".txt", ".rtf"}

    root = Path(root_path)
    total = 0
    docs = []

    for current, dirs, files in os.walk(root):
        dirs.sort()
        files.sort()
        for fname in files:
            p = Path(current) / fname
            if p.suffix.lower() in exts:
                try:
                    sz = p.stat().st_size
                except OSError:
                    continue
                rel = p.relative_to(root)
                docs.append((rel, sz))
                total += sz

    # Print
    if docs:
        print("\nDocuments (in tree order):")
        for rel, sz in docs:
            print(f"- {rel.as_posix()}  ({human_size(sz)})")
        print(f"\nTotal documents: {len(docs)}, total size: {human_size(total)}")
    else:
        print("\nNo documents found with the chosen extensions.")

# --- Run ---
print_tree(ROOT)
print_documents_with_sizes(ROOT)
# Out:
# first_aid_knowledge_pack_v3/
#     .DS_Store
#     manifest.yaml
#     assets/
#         .DS_Store
#         bleeding/
#             pressure.png
#             tourniquet.png
#         burns/
#             cool_water.png
#             cover.png
#         child-illness/
#             fever.png
#         choking-cpr/
#             hands_only_cpr.png
#             heimlich.png
#         contacts/
#             office.png
#         diarrhea/
#             ors.png
#         education/
#             school.png
#         flood-wounds/
#             wound.png
#         fractures/
#             splint.png
#         heat/
#             cooling.png
#             shade.png
#         joint-pain/
#             rest.png
#         maternal/
#             warning.png
#         pesticides/
#             safety.png
#         rainwater/
#             collection.png
#         rash/
#             plant_contact.png
#         safe-water/
#             boil.png
#         snakebite/
#             immobilize.png
#             no_cut.png
#         transport/
#             bus.png
#         water-storage/
#             containers.png
#         wild-animals/
#             fence.png
#     core/
#         .DS_Store
#         bleeding/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 EN_GFARC_GUIDELINES_2020.pdf
#                 FA-manual-Ind-Red-Cross.pdf
#         burns/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 9789241501187_eng.pdf
#                 EN_GFARC_GUIDELINES_2020.pdf
#         child-illness/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 9789241548045_Manual_eng.pdf
#         choking-cpr/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 EN_GFARC_GUIDELINES_2020.pdf
#                 ISA-IRC-COLS-Guidelines.pdf
#         contacts/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 Bihar_Applicant_User_Manual.pdf
#                 S.D.P.O_contact.pdf
#                 phc_list_bihar.pdf
#         diarrhea/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 imnci_chart_booklet.pdf
#                 treament of DIARRHEA.pdf
#         education/
#             .DS_Store
#             User_Manual_for_BSCCpdf1.pdf
#             hi_en/
#                 .DS_Store
#         fractures/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 EN_GFARC_GUIDELINES_2020.pdf
#                 Fact-sheets_fracture-and-dislocation.pdf
#         heat/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 2-Training-Manual-for-Community-Members-Recognising-and-Preventing-Heat-Related-Illnesses.pdf
#                 ahmedabad-heat-action-plan-2018.pdf
#         infected-wounds/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 Induction-Training-Module-for-ASHA-English_0.pdf
#         joint-pain/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 Ergonomic checkpoints in agriculture.pdf
#                 pl-950.1-lower-back-pain.pdf
#         maternal/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 9789241549295_ParticipantManual_eng.pdf
#                 maternal-health-asha.pdf
#         pesticides/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 cb3963en.pdf
#         rash/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 IntegratedPartheniumManagement(Elglish)-Folder.pdf
#                 cdc-rashes-plant.pdf
#         safe-water/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 who-tn-01-cleaning-and-disinfecting-wells.pdf
#                 who-tn-03-cleaning-and-disinfecting-water-storage-tanks-and-tankers.pdf
#                 who-tn-05-emergency-treatment-of-drinking-water-at-the-point-of-use.pdf
#         snakebite/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 English-Booklet_compressed.pdf
#                 who-guidance-on-snakebites.pdf
#         transport/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 SOP-OF-AMBULANCE2020IPTHHScompressed.pdf
#         water-harvesting/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 CAWSTRWH_Manual_2011-11_en.pdf
#                 sites-PD-WASH-WASH Knowledge unicef-Rooftop Rainwater Harvesting Odisha-2.0.pdf
#         water-storage/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 who-tn-09-how-much-water-is-needed.pdf
#         wild-animals/
#             .DS_Store
#             hi_en/
#                 .DS_Store
#                 Advisory for Priority of Action for State Govt-Human Wildlife Conflict_0.pdf
#                 National-Human-Wildlife-Conflict-Mitigation-Strategy-and-Action-Plan-of-India-2.pdf
#     vector_db/
#         images/
#             captions.jsonl
#             embeddings.jsonl
#             index.bin
#             meta.json
#             faiss_index/
#                 index.faiss
#                 index.pkl
#         text/
#             embeddings.jsonl
#             meta.json
#             faiss_index/
#                 index.faiss
#                 index.pkl
#
# Documents (in tree order):
# - core/bleeding/hi_en/EN_GFARC_GUIDELINES_2020.pdf  (4.2MB)
# - core/bleeding/hi_en/FA-manual-Ind-Red-Cross.pdf  (10MB)
# - core/burns/hi_en/9789241501187_eng.pdf  (3.8MB)
# - core/burns/hi_en/EN_GFARC_GUIDELINES_2020.pdf  (4.2MB)
# - core/child-illness/hi_en/9789241548045_Manual_eng.pdf  (3.4MB)
# - core/choking-cpr/hi_en/EN_GFARC_GUIDELINES_2020.pdf  (4.2MB)
# - core/choking-cpr/hi_en/ISA-IRC-COLS-Guidelines.pdf  (1.1MB)
# - core/contacts/hi_en/Bihar_Applicant_User_Manual.pdf  (1.6MB)
# - core/contacts/hi_en/S.D.P.O_contact.pdf  (201KB)
# - core/contacts/hi_en/phc_list_bihar.pdf  (763KB)
# - core/diarrhea/hi_en/imnci_chart_booklet.pdf  (2.4MB)
# - core/diarrhea/hi_en/treament of DIARRHEA.pdf  (1.0MB)
# - core/education/User_Manual_for_BSCCpdf1.pdf  (1.6MB)
# - core/fractures/hi_en/EN_GFARC_GUIDELINES_2020.pdf  (4.2MB)
# - core/fractures/hi_en/Fact-sheets_fracture-and-dislocation.pdf  (119KB)
# - core/heat/hi_en/2-Training-Manual-for-Community-Members-Recognising-and-Preventing-Heat-Related-Illnesses.pdf  (1.1MB)
# - core/heat/hi_en/ahmedabad-heat-action-plan-2018.pdf  (4.6MB)
# - core/infected-wounds/hi_en/Induction-Training-Module-for-ASHA-English_0.pdf  (4.3MB)
# - core/joint-pain/hi_en/Ergonomic checkpoints in agriculture.pdf  (4.0MB)
# - core/joint-pain/hi_en/pl-950.1-lower-back-pain.pdf  (879KB)
# - core/maternal/hi_en/9789241549295_ParticipantManual_eng.pdf  (1.6MB)
# - core/maternal/hi_en/maternal-health-asha.pdf  (3.3MB)
# - core/pesticides/hi_en/cb3963en.pdf  (3.4MB)
# - core/rash/hi_en/IntegratedPartheniumManagement(Elglish)-Folder.pdf  (985KB)
# - core/rash/hi_en/cdc-rashes-plant.pdf  (1018KB)
# - core/safe-water/hi_en/who-tn-01-cleaning-and-disinfecting-wells.pdf  (874KB)
# - core/safe-water/hi_en/who-tn-03-cleaning-and-disinfecting-water-storage-tanks-and-tankers.pdf  (982KB)
# - core/safe-water/hi_en/who-tn-05-emergency-treatment-of-drinking-water-at-the-point-of-use.pdf  (1.3MB)
# - core/snakebite/hi_en/English-Booklet_compressed.pdf  (1.5MB)
# - core/snakebite/hi_en/who-guidance-on-snakebites.pdf  (4.7MB)
# - core/transport/hi_en/SOP-OF-AMBULANCE2020IPTHHScompressed.pdf  (3.8MB)
# - core/water-harvesting/hi_en/CAWSTRWH_Manual_2011-11_en.pdf  (3.1MB)
# - core/water-harvesting/hi_en/sites-PD-WASH-WASH Knowledge unicef-Rooftop Rainwater Harvesting Odisha-2.0.pdf  (1.0MB)
# - core/water-storage/hi_en/who-tn-09-how-much-water-is-needed.pdf  (875KB)
# - core/wild-animals/hi_en/Advisory for Priority of Action for State Govt-Human Wildlife Conflict_0.pdf  (718KB)
# - core/wild-animals/hi_en/National-Human-Wildlife-Conflict-Mitigation-Strategy-and-Action-Plan-of-India-2.pdf  (25MB)
#
# Total documents: 36, total size: 112MB

# %%
from pathlib import Path
import os

ROOT = "/Users/ktejwani/Personal CS Projects/Summer 2025/Offline AI Kiosk/Offline-AI-Kiosk/first_aid_knowledge_pack_v3"

def human_size(num_bytes: int) -> str:
    units = ["B", "KB", "MB", "GB", "TB"]
    size = float(num_bytes)
    for u in units:
        if size < 1024 or u == units[-1]:
            return f"{size:.0f}{u}" if size >= 10 else f"{size:.1f}{u}"
        size /= 1024

def print_tree(root_path: str):
    """Print the file tree with ├── and └── style branches, skipping hidden files like .DS_Store."""
    root = Path(root_path)
    if not root.exists() or not root.is_dir():
        raise NotADirectoryError(f"{root} is not a directory")

    def _tree(dir_path: Path, prefix: str = ""):
        entries = sorted(
            [p for p in dir_path.iterdir() if not p.name.startswith(".")],
            key=lambda p: (p.is_file(), p.name.lower())
        )
        count = len(entries)
        for idx, entry in enumerate(entries):
            connector = "└── " if idx == count - 1 else "├── "
            print(prefix + connector + entry.name)
            if entry.is_dir():
                extension = "    " if idx == count - 1 else "│   "
                _tree(entry, prefix + extension)

    print(f"{root.name}/")
    _tree(root)

def print_documents_with_sizes(root_path: str, exts=None):
    """
    Print all 'documents' in tree order with sizes.
    Default extensions: .pdf, .doc, .docx, .md, .txt, .rtf
    """
    if exts is None:
        exts = {".pdf", ".doc", ".docx", ".md", ".txt", ".rtf"}

    root = Path(root_path)
    total = 0
    docs = []

    for current, dirs, files in os.walk(root):
        # skip hidden dirs
        dirs[:] = [d for d in dirs if not d.startswith(".")]
        for fname in sorted(files):
            if fname.startswith("."):
                continue
            p = Path(current) / fname
            if p.suffix.lower() in exts:
                try:
                    sz = p.stat().st_size
                except OSError:
                    continue
                rel = p.relative_to(root)
                docs.append((rel, sz))
                total += sz

    # Print
    if docs:
        print("\nDocuments (in tree order):")
        for rel, sz in docs:
            print(f"- {rel.as_posix()}  ({human_size(sz)})")
        print(f"\nTotal documents: {len(docs)}, total size: {human_size(total)}")
    else:
        print("\nNo documents found with the chosen extensions.")

# --- Run ---
print_tree(ROOT)
print_documents_with_sizes(ROOT)
# Out:
# first_aid_knowledge_pack_v3/
# ├── assets
# │   ├── bleeding
# │   │   ├── pressure.png
# │   │   └── tourniquet.png
# │   ├── burns
# │   │   ├── cool_water.png
# │   │   └── cover.png
# │   ├── child-illness
# │   │   └── fever.png
# │   ├── choking-cpr
# │   │   ├── hands_only_cpr.png
# │   │   └── heimlich.png
# │   ├── contacts
# │   │   └── office.png
# │   ├── diarrhea
# │   │   └── ors.png
# │   ├── education
# │   │   └── school.png
# │   ├── flood-wounds
# │   │   └── wound.png
# │   ├── fractures
# │   │   └── splint.png
# │   ├── heat
# │   │   ├── cooling.png
# │   │   └── shade.png
# │   ├── joint-pain
# │   │   └── rest.png
# │   ├── maternal
# │   │   └── warning.png
# │   ├── pesticides
# │   │   └── safety.png
# │   ├── rainwater
# │   │   └── collection.png
# │   ├── rash
# │   │   └── plant_contact.png
# │   ├── safe-water
# │   │   └── boil.png
# │   ├── snakebite
# │   │   ├── immobilize.png
# │   │   └── no_cut.png
# │   ├── transport
# │   │   └── bus.png
# │   ├── water-storage
# │   │   └── containers.png
# │   └── wild-animals
# │       └── fence.png
# ├── core
# │   ├── bleeding
# │   │   └── hi_en
# │   │       ├── EN_GFARC_GUIDELINES_2020.pdf
# │   │       └── FA-manual-Ind-Red-Cross.pdf
# │   ├── burns
# │   │   └── hi_en
# │   │       ├── 9789241501187_eng.pdf
# │   │       └── EN_GFARC_GUIDELINES_2020.pdf
# │   ├── child-illness
# │   │   └── hi_en
# │   │       └── 9789241548045_Manual_eng.pdf
# │   ├── choking-cpr
# │   │   └── hi_en
# │   │       ├── EN_GFARC_GUIDELINES_2020.pdf
# │   │       └── ISA-IRC-COLS-Guidelines.pdf
# │   ├── contacts
# │   │   └── hi_en
# │   │       ├── Bihar_Applicant_User_Manual.pdf
# │   │       ├── phc_list_bihar.pdf
# │   │       └── S.D.P.O_contact.pdf
# │   ├── diarrhea
# │   │   └── hi_en
# │   │       ├── imnci_chart_booklet.pdf
# │   │       └── treament of DIARRHEA.pdf
# │   ├── education
# │   │   └── hi_en
# │   │       └── User_Manual_for_BSCCpdf1.pdf
# │   ├── fractures
# │   │   └── hi_en
# │   │       ├── EN_GFARC_GUIDELINES_2020.pdf
# │   │       └── Fact-sheets_fracture-and-dislocation.pdf
# │   ├── heat
# │   │   └── hi_en
# │   │       ├── 2-Training-Manual-for-Community-Members-Recognising-and-Preventing-Heat-Related-Illnesses.pdf
# │   │       └── ahmedabad-heat-action-plan-2018.pdf
# │   ├── infected-wounds
# │   │   └── hi_en
# │   │       └── Induction-Training-Module-for-ASHA-English_0.pdf
# │   ├── joint-pain
# │   │   └── hi_en
# │   │       ├── Ergonomic checkpoints in agriculture.pdf
# │   │       └── pl-950.1-lower-back-pain.pdf
# │   ├── maternal
# │   │   └── hi_en
# │   │       ├── 9789241549295_ParticipantManual_eng.pdf
# │   │       └── maternal-health-asha.pdf
# │   ├── pesticides
# │   │   └── hi_en
# │   │       └── cb3963en.pdf
# │   ├── rash
# │   │   └── hi_en
# │   │       ├── cdc-rashes-plant.pdf
# │   │       └── IntegratedPartheniumManagement(Elglish)-Folder.pdf
# │   ├── safe-water
# │   │   └── hi_en
# │   │       ├── who-tn-01-cleaning-and-disinfecting-wells.pdf
# │   │       ├── who-tn-03-cleaning-and-disinfecting-water-storage-tanks-and-tankers.pdf
# │   │       └── who-tn-05-emergency-treatment-of-drinking-water-at-the-point-of-use.pdf
# │   ├── snakebite
# │   │   └── hi_en
# │   │       ├── English-Booklet_compressed.pdf
# │   │       └── who-guidance-on-snakebites.pdf
# │   ├── transport
# │   │   └── hi_en
# │   │       └── SOP-OF-AMBULANCE2020IPTHHScompressed.pdf
# │   ├── water-harvesting
# │   │   └── hi_en
# │   │       ├── CAWSTRWH_Manual_2011-11_en.pdf
# │   │       └── sites-PD-WASH-WASH Knowledge unicef-Rooftop Rainwater Harvesting Odisha-2.0.pdf
# │   ├── water-storage
# │   │   └── hi_en
# │   │       └── who-tn-09-how-much-water-is-needed.pdf
# │   └── wild-animals
# │       └── hi_en
# │           ├── Advisory for Priority of Action for State Govt-Human Wildlife Conflict_0.pdf
# │           └── National-Human-Wildlife-Conflict-Mitigation-Strategy-and-Action-Plan-of-India-2.pdf
# ├── vector_db
# │   ├── images
# │   │   ├── faiss_index
# │   │   │   ├── index.faiss
# │   │   │   └── index.pkl
# │   │   ├── captions.jsonl
# │   │   ├── embeddings.jsonl
# │   │   ├── index.bin
# │   │   └── meta.json
# │   └── text
# │       ├── faiss_index
# │       │   ├── index.faiss
# │       │   └── index.pkl
# │       ├── embeddings.jsonl
# │       └── meta.json
# └── manifest.yaml
#
# Documents (in tree order):
# - core/heat/hi_en/2-Training-Manual-for-Community-Members-Recognising-and-Preventing-Heat-Related-Illnesses.pdf  (1.1MB)
# - core/heat/hi_en/ahmedabad-heat-action-plan-2018.pdf  (4.6MB)
# - core/transport/hi_en/SOP-OF-AMBULANCE2020IPTHHScompressed.pdf  (3.8MB)
# - core/water-storage/hi_en/who-tn-09-how-much-water-is-needed.pdf  (875KB)
# - core/joint-pain/hi_en/Ergonomic checkpoints in agriculture.pdf  (4.0MB)
# - core/joint-pain/hi_en/pl-950.1-lower-back-pain.pdf  (879KB)
# - core/child-illness/hi_en/9789241548045_Manual_eng.pdf  (3.4MB)
# - core/bleeding/hi_en/EN_GFARC_GUIDELINES_2020.pdf  (4.2MB)
# - core/bleeding/hi_en/FA-manual-Ind-Red-Cross.pdf  (10MB)
# - core/infected-wounds/hi_en/Induction-Training-Module-for-ASHA-English_0.pdf  (4.3MB)
# - core/contacts/hi_en/Bihar_Applicant_User_Manual.pdf  (1.6MB)
# - core/contacts/hi_en/S.D.P.O_contact.pdf  (201KB)
# - core/contacts/hi_en/phc_list_bihar.pdf  (763KB)
# - core/education/hi_en/User_Manual_for_BSCCpdf1.pdf  (1.6MB)
# - core/wild-animals/hi_en/Advisory for Priority of Action for State Govt-Human Wildlife Conflict_0.pdf  (718KB)
# - core/wild-animals/hi_en/National-Human-Wildlife-Conflict-Mitigation-Strategy-and-Action-Plan-of-India-2.pdf  (25MB)
# - core/choking-cpr/hi_en/EN_GFARC_GUIDELINES_2020.pdf  (4.2MB)
# - core/choking-cpr/hi_en/ISA-IRC-COLS-Guidelines.pdf  (1.1MB)
# - core/safe-water/hi_en/who-tn-01-cleaning-and-disinfecting-wells.pdf  (874KB)
# - core/safe-water/hi_en/who-tn-03-cleaning-and-disinfecting-water-storage-tanks-and-tankers.pdf  (982KB)
# - core/safe-water/hi_en/who-tn-05-emergency-treatment-of-drinking-water-at-the-point-of-use.pdf  (1.3MB)
# - core/snakebite/hi_en/English-Booklet_compressed.pdf  (1.5MB)
# - core/snakebite/hi_en/who-guidance-on-snakebites.pdf  (4.7MB)
# - core/maternal/hi_en/9789241549295_ParticipantManual_eng.pdf  (1.6MB)
# - core/maternal/hi_en/maternal-health-asha.pdf  (3.3MB)
# - core/burns/hi_en/9789241501187_eng.pdf  (3.8MB)
# - core/burns/hi_en/EN_GFARC_GUIDELINES_2020.pdf  (4.2MB)
# - core/fractures/hi_en/EN_GFARC_GUIDELINES_2020.pdf  (4.2MB)
# - core/fractures/hi_en/Fact-sheets_fracture-and-dislocation.pdf  (119KB)
# - core/rash/hi_en/IntegratedPartheniumManagement(Elglish)-Folder.pdf  (985KB)
# - core/rash/hi_en/cdc-rashes-plant.pdf  (1018KB)
# - core/water-harvesting/hi_en/CAWSTRWH_Manual_2011-11_en.pdf  (3.1MB)
# - core/water-harvesting/hi_en/sites-PD-WASH-WASH Knowledge unicef-Rooftop Rainwater Harvesting Odisha-2.0.pdf  (1.0MB)
# - core/pesticides/hi_en/cb3963en.pdf  (3.4MB)
# - core/diarrhea/hi_en/imnci_chart_booklet.pdf  (2.4MB)
# - core/diarrhea/hi_en/treament of DIARRHEA.pdf  (1.0MB)
#
# Total documents: 36, total size: 112MB
